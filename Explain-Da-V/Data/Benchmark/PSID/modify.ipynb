# %%
import pandas as pd
data = pd.read_csv('psid.csv', keep_default_na=False, na_values=[""])
data = data.reset_index(drop=True)
data['orig_index'] = data.index

# %%
data_ver_0 = data.drop(columns=['earning_change', 'orig_index'])
data_ver_1 = data

# %%
data_ver_0.to_csv("data_ver_0.csv", index=False)
data_ver_1.to_csv("data_ver_1.csv", index=False)

# %%
data_ver_1.drop(columns=['orig_index'])
# Out:
#          sex  release_number_2019 school_internet_usage_frequency_2019  \
# 0     female                  2.0                            every_day
# 1       male                  2.0           not_in_school_past_30_days
# 2       male                  2.0           not_in_school_past_30_days
# 3       male                  2.0           not_in_school_past_30_days
# 4       male                  2.0           not_in_school_past_30_days
# ...      ...                  ...                                  ...
# 2446  female                  2.0                     few_times_a_week
# 2447    male                  2.0           not_in_school_past_30_days
# 2448  female                  2.0                            every_day
# 2449  female                  2.0           not_in_school_past_30_days
# 2450    male                  2.0           not_in_school_past_30_days
#
#      job_internet_usage_frequency_2019 happiness_frequency_last_month_2019  \
# 0                                never                           every_day
# 1                     few_times_a_week                    almost_every_day
# 2                                never                    almost_every_day
# 3             not_working_past_30_days                           every_day
# 4                                never                    almost_every_day
# ...                                ...                                 ...
# 2446                         every_day                    almost_every_day
# 2447                  few_times_a_week                    almost_every_day
# 2448                         every_day                               never
# 2449                             never                    almost_every_day
# 2450                             never                    almost_every_day
#
#      interest_in_life_frequency_last_month_2019  \
# 0                                     every_day
# 1                                     every_day
# 2                              almost_every_day
# 3                                     every_day
# 4                              almost_every_day
# ...                                         ...
# 2446                           almost_every_day
# 2447                           almost_every_day
# 2448                                      never
# 2449                           almost_every_day
# 2450                           almost_every_day
#
#      satisfaction_frequency_last_month_2019  \
# 0                                 every_day
# 1                             once_or_twice
# 2                          almost_every_day
# 3                                 every_day
# 4                 two_or_three_times_a_week
# ...                                     ...
# 2446              two_or_three_times_a_week
# 2447                       almost_every_day
# 2448                                  never
# 2449                       almost_every_day
# 2450              two_or_three_times_a_week
#
#      contribution_to_society_frequency_2019  \
# 0                                 every_day
# 1                                 every_day
# 2                          almost_every_day
# 3                                 every_day
# 4                             once_or_twice
# ...                                     ...
# 2446                       almost_every_day
# 2447                       almost_every_day
# 2448                                  never
# 2449                              every_day
# 2450                      about_once_a_week
#
#      community_belonging_frequency_2019 society_getting_better_frequency_2019  \
# 0                             every_day                                 never
# 1                             every_day                                 never
# 2                      almost_every_day             two_or_three_times_a_week
# 3                      almost_every_day             two_or_three_times_a_week
# 4                                 never                                 never
# ...                                 ...                                   ...
# 2446                      once_or_twice                                 never
# 2447                   almost_every_day                     about_once_a_week
# 2448                              never                                 never
# 2449                   almost_every_day                                 never
# 2450                              never                         once_or_twice
#
#       ... checking_savings_total_amount_usd_2019  \
# 0     ...                           0.000000e+00
# 1     ...                           3.000000e+02
# 2     ...                           0.000000e+00
# 3     ...                           0.000000e+00
# 4     ...                           0.000000e+00
# ...   ...                                    ...
# 2446  ...                           3.000000e+03
# 2447  ...                           0.000000e+00
# 2448  ...                          -1.330000e+02
# 2449  ...                           2.000000e+02
# 2450  ...                           1.000000e+10
#
#      credit_card_debt_total_usd_2019 went_without_health_insurance_2017_2018  \
# 0                                0.0                                     yes
# 1                                0.0                                      no
# 2                                0.0                                     yes
# 3                                0.0                                      no
# 4                              300.0                                      no
# ...                              ...                                     ...
# 2446                          4200.0                                      no
# 2447                             0.0                                      no
# 2448                             0.0                                     yes
# 2449                          2500.0                                      no
# 2450                             0.0                                     yes
#
#      drinks_alcohol_2019 ever_arrested times_arrested  \
# 0                    yes            no            0.0
# 1                    yes            no            0.0
# 2                    yes            no            0.0
# 3                    yes            no            0.0
# 4                     no            no            0.0
# ...                  ...           ...            ...
# 2446                  no            no            0.0
# 2447                 yes           yes            1.0
# 2448                  no           yes            3.0
# 2449                 yes            no            0.0
# 2450                 yes            no            0.0
#
#      ethnic_identity_importance_2019 current_state_fips_2019  \
# 0               not_at_all_important               Tennessee
# 1                extremely_important               Tennessee
# 2               not_at_all_important               Tennessee
# 3               not_at_all_important                    Ohio
# 4               not_at_all_important                    Ohio
# ...                              ...                     ...
# 2446                  very_important              California
# 2447              somewhat_important                Maryland
# 2448             extremely_important                   Texas
# 2449             extremely_important                   Texas
# 2450                  very_important                   Texas
#
#      earnings_job_2018 earning_change
# 0              40000.0       -40000.0
# 1              30000.0       -27985.0
# 2                 11.0          -11.0
# 3              63000.0       -63000.0
# 4              26000.0       -26000.0
# ...                ...            ...
# 2446           60000.0       -60000.0
# 2447              24.0          -24.0
# 2448               8.5           -8.5
# 2449              15.0          -15.0
# 2450             500.0         -500.0
#
# [2451 rows x 44 columns]

# %%
from sklearn.model_selection import train_test_split
# I fucked up... 
# Generate indices split once
train_idx, test_idx = train_test_split(
    data.index,
    test_size=0.2,
    random_state=42,
    shuffle=True
)

# Apply split
data_ver_2 = data_ver_0.loc[train_idx].reset_index(drop=True)
data_ver_3  = data_ver_0.loc[test_idx].reset_index(drop=True)


data_ver_4 = data_ver_1.loc[train_idx].reset_index(drop=True)
data_ver_4['orig_index'] = data_ver_4.index
data_ver_5  = data_ver_1.loc[test_idx].reset_index(drop=True)
data_ver_5['orig_index'] = data_ver_5.index

# %%
data_ver_2.to_csv("data_ver_2.csv", index=False)
data_ver_3.to_csv("data_ver_3.csv", index=False)
data_ver_4.to_csv("data_ver_4.csv", index=False)
data_ver_5.to_csv("data_ver_5.csv", index=False)
